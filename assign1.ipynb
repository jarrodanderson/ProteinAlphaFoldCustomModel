# %%
import torch
import torch.onnx
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt

import multiprocessing
import os
import pickle
import random

import gensim
import numpy as np
import pandas as pd
from gensim.models.doc2vec import Doc2Vec, TaggedDocument


# in the .py file add the command line args here
filename = 'small_uniprot.txt'
embed_dim = 100
context_sz = 25
ngram_size = 10
neg_samples = 10


sequence_dict = {}
sequence_dict['small'] = pd.read_csv('sequence_data/'+filename)
#print(sequence_dict['small'])


def train(X, k, window):
  print(X, k,window)

# %% [markdown]
# # New Section

# %%
for k in range(1, 6):
        for window in range(1, 8):
            train("small_uniprot.txt", k, window)
# Out:
# small_uniprot.txt 1 1
# small_uniprot.txt 1 2
# small_uniprot.txt 1 3
# small_uniprot.txt 1 4
# small_uniprot.txt 1 5
# small_uniprot.txt 1 6
# small_uniprot.txt 1 7
# small_uniprot.txt 2 1
# small_uniprot.txt 2 2
# small_uniprot.txt 2 3
# small_uniprot.txt 2 4
# small_uniprot.txt 2 5
# small_uniprot.txt 2 6
# small_uniprot.txt 2 7
# small_uniprot.txt 3 1
# small_uniprot.txt 3 2
# small_uniprot.txt 3 3
# small_uniprot.txt 3 4
# small_uniprot.txt 3 5
# small_uniprot.txt 3 6
# small_uniprot.txt 3 7
# small_uniprot.txt 4 1
# small_uniprot.txt 4 2
# small_uniprot.txt 4 3
# small_uniprot.txt 4 4
# small_uniprot.txt 4 5
# small_uniprot.txt 4 6
# small_uniprot.txt 4 7
# small_uniprot.txt 5 1
# small_uniprot.txt 5 2
# small_uniprot.txt 5 3
# small_uniprot.txt 5 4
# small_uniprot.txt 5 5
# small_uniprot.txt 5 6
# small_uniprot.txt 5 7
